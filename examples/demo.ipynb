# %%
from abc import ABC, abstractmethod

class StockAPI:

    @abstractmethod
    def get_daily(self, symbol, **kwargs):
        pass

    @abstractmethod
    def get_intraday(self, symbol, **kwargs):
        pass

    @abstractmethod
    def get_weekly(self, symbol, **kwargs):
        pass

    @abstractmethod
    def get_monthly(self, symbol, **kwargs):
        pass

# %%
import requests

OUTPUT_SIZES = ['compact', 'full']
DATA_TYPES = ['json', 'csv']
INTRADAY_INTERVALS = ['1min', '5min', '15min', '30min', '60min']

class AlphaVantageStockAPI(StockAPI):  

    def __init__(self, api_key):
        self.api_key = api_key


    def call_api(self, endpoint):
        response = requests.get(endpoint)
        if response.status_code != 200:
            raise ValueError(f'Invalid API response: {response}')
        return response


    def get_daily(self, symbol, adjusted=False, outputsize='compact', datatype='json'):
        """ Get daily stock data for a given symbol. """
        if outputsize not in OUTPUT_SIZES:
            raise ValueError(f'outputsize must be one of {OUTPUT_SIZES}')
        if datatype not in DATA_TYPES:
            raise ValueError(f'datatype must be one of {DATA_TYPES}')
        
        if adjusted:
            function = 'TIME_SERIES_DAILY_ADJUSTED'
        else:
            function = 'TIME_SERIES_DAILY'

        endpoint = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}'
        if outputsize == 'full':
            endpoint += '&outputsize=full'
        if datatype == 'csv':
            endpoint += '&datatype=csv'
        endpoint += f'&apikey={self.api_key}'

        return self.call_api(endpoint)
    

    def get_intraday(self, symbol, interval='5min', adjusted=True, extended_hours=True,
                    month=None, outputsize='compact', datatype='json'):
        """ Get intraday stock data for a given symbol."""
        if outputsize not in OUTPUT_SIZES:
            raise ValueError(f'outputsize must be one of {OUTPUT_SIZES}')
        if datatype not in DATA_TYPES:
            raise ValueError(f'datatype must be one of {DATA_TYPES}')
        if interval not in INTRADAY_INTERVALS:
            raise ValueError(f'interval must be one of {INTRADAY_INTERVALS}')
        
        endpoint = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={symbol}&interval={interval}'
        if month is not None:
            endpoint += f'&month={month}'
        if not adjusted:
            endpoint += '&adjusted=false'
        if not extended_hours:
            endpoint += '&extended_hours=false'
        if outputsize == 'full':
            endpoint += '&outputsize=full'
        if datatype == 'csv':
            endpoint += '&datatype=csv'
        endpoint += f'&apikey={self.api_key}'
        
        return self.call_api(endpoint)       


    def get_weekly(self, symbol, adjusted=False, datatype='json'):
        """ Get weekly stock data for a given symbol."""
        if datatype not in DATA_TYPES:
            raise ValueError(f'datatype must be one of {DATA_TYPES}')
        if adjusted:
            function = 'TIME_SERIES_WEEKLY_ADJUSTED'
        else:
            function = 'TIME_SERIES_WEEKLY'

        endpoint = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}'
        if datatype == 'csv':
            endpoint += '&datatype=csv'
        endpoint += f'&apikey={self.api_key}'

        return self.call_api(endpoint)
    

    def get_monthly(self, symbol, adjusted=False, datatype='json'):
        """ Get monthly stock data for a given symbol."""
        if datatype not in DATA_TYPES:
            raise ValueError(f'datatype must be one of {DATA_TYPES}')
        if adjusted:
            function = 'TIME_SERIES_MONTHLY_ADJUSTED'
        else:
            function = 'TIME_SERIES_MONTHLY'

        endpoint = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}'
        if datatype == 'csv':
            endpoint += '&datatype=csv'
        endpoint += f'&apikey={self.api_key}'

        return self.call_api(endpoint)
    

    def search_symbol(self, keywords, datatype='json'):
        """ Search for a symbol based on keywords. """""
        if datatype not in DATA_TYPES:
            raise ValueError(f'datatype must be one of {DATA_TYPES}')
        
        endpoint = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={keywords}'
        if datatype == 'csv':
            endpoint += '&datatype=csv'
        endpoint += f'&apikey={self.api_key}'

        return self.call_api(endpoint)
    
    def global_market_status(self):
        """ Get the current global market status. """
        endpoint = f'https://www.alphavantage.co/query?function=MARKET_STATUS&apikey={self.api_key}'
        
        return self.call_api(endpoint)

# %%
key = 'QSDYF6K3UBL8S8SP'
api = AlphaVantageStockAPI('demo')
response = api.get_daily('IBM', adjusted=True)
response.json()
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2023-11-29',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-11-29': {'1. open': '156.15',
#    '2. high': '157.51',
#    '3. low': '156.02',
#    '4. close': '156.41',
#    '5. adjusted close': '156.41',
#    '6. volume': '3568887',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-28': {'1. open': '155.44',
#    '2. high': '155.745',
#    '3. low': '154.86',
#    '4. close': '155.65',
#    '5. adjusted close': '155.65',
#    '6. volume': '2666182',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-27': {'1. open': '154.99',
#    '2. high': '156.135',
#    '3. low': '154.75',
#    '4. close': '155.57',
#    '5. adjusted close': '155.57',
#    '6. volume': '4053093',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-24': {'1. open': '155.13',
#    '2. high': '155.4',
#    '3. low': '153.92',
#    '4. close': '155.18',
#    '5. adjusted close': '155.18',
#    '6. volume': '1799161',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-22': {'1. open': '154.5',
#    '2. high': '155.705',
#    '3. low': '154.16',
#    '4. close': '155.13',
#    '5. adjusted close': '155.13',
#    '6. volume': '3045091',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-21': {'1. open': '154.6',
#    '2. high': '154.66',
#    '3. low': '153.51',
#    '4. close': '153.91',
#    '5. adjusted close': '153.91',
#    '6. volume': '2859508',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-20': {'1. open': '152.51',
#    '2. high': '154.68',
#    '3. low': '152.35',
#    '4. close': '154.35',
#    '5. adjusted close': '154.35',
#    '6. volume': '3658936',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-17': {'1. open': '153.29',
#    '2. high': '153.5',
#    '3. low': '152.4601',
#    '4. close': '152.89',
#    '5. adjusted close': '152.89',
#    '6. volume': '4426676',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-16': {'1. open': '153.0',
#    '2. high': '153.35',
#    '3. low': '152.13',
#    '4. close': '153.06',
#    '5. adjusted close': '153.06',
#    '6. volume': '3519172',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-15': {'1. open': '150.4',
#    '2. high': '153.22',
#    '3. low': '150.4',
#    '4. close': '152.58',
#    '5. adjusted close': '152.58',
#    '6. volume': '4632519',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-14': {'1. open': '149.45',
#    '2. high': '150.8063',
#    '3. low': '149.05',
#    '4. close': '150.41',
#    '5. adjusted close': '150.41',
#    '6. volume': '4321940',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-13': {'1. open': '148.46',
#    '2. high': '148.49',
#    '3. low': '147.35',
#    '4. close': '148.1',
#    '5. adjusted close': '148.1',
#    '6. volume': '2647288',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-10': {'1. open': '147.44',
#    '2. high': '149.17',
#    '3. low': '146.85',
#    '4. close': '149.02',
#    '5. adjusted close': '149.02',
#    '6. volume': '3179541',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-09': {'1. open': '146.55',
#    '2. high': '146.99',
#    '3. low': '145.28',
#    '4. close': '146.62',
#    '5. adjusted close': '146.62',
#    '6. volume': '3412713',
#    '7. dividend amount': '1.6600',
#    '8. split coefficient': '1.0'},
#   '2023-11-08': {'1. open': '149.25',
#    '2. high': '149.68',
#    '3. low': '147.585',
#    '4. close': '148.03',
#    '5. adjusted close': '146.372798759104',
#    '6. volume': '3618588',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-07': {'1. open': '149.03',
#    '2. high': '149.28',
#    '3. low': '148.03',
#    '4. close': '148.83',
#    '5. adjusted close': '147.16384272997',
#    '6. volume': '3549853',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-06': {'1. open': '147.89',
#    '2. high': '149.225',
#    '3. low': '147.85',
#    '4. close': '148.97',
#    '5. adjusted close': '147.302275424872',
#    '6. volume': '4597249',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-03': {'1. open': '147.45',
#    '2. high': '148.445',
#    '3. low': '147.28',
#    '4. close': '147.9',
#    '5. adjusted close': '146.244254113839',
#    '6. volume': '3510495',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-02': {'1. open': '145.77',
#    '2. high': '147.1',
#    '3. low': '144.84',
#    '4. close': '147.01',
#    '5. adjusted close': '145.36421769625',
#    '6. volume': '3902657',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-11-01': {'1. open': '145.0',
#    '2. high': '146.51',
#    '3. low': '144.45',
#    '4. close': '145.4',
#    '5. adjusted close': '143.772241704883',
#    '6. volume': '4750081',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-31': {'1. open': '143.0',
#    '2. high': '144.76',
#    '3. low': '142.59',
#    '4. close': '144.64',
#    '5. adjusted close': '143.02074993256',
#    '6. volume': '6592041',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-30': {'1. open': '143.19',
#    '2. high': '144.5',
#    '3. low': '142.58',
#    '4. close': '142.63',
#    '5. adjusted close': '141.033251955759',
#    '6. volume': '4204190',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-27': {'1. open': '143.62',
#    '2. high': '144.7',
#    '3. low': '141.71',
#    '4. close': '142.52',
#    '5. adjusted close': '140.924483409765',
#    '6. volume': '5469227',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-26': {'1. open': '142.2',
#    '2. high': '144.41',
#    '3. low': '141.58',
#    '4. close': '143.76',
#    '5. adjusted close': '142.150601564607',
#    '6. volume': '11130170',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-25': {'1. open': '137.5',
#    '2. high': '138.49',
#    '3. low': '136.33',
#    '4. close': '137.08',
#    '5. adjusted close': '135.545384407877',
#    '6. volume': '6472549',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-24': {'1. open': '136.74',
#    '2. high': '137.98',
#    '3. low': '136.05',
#    '4. close': '137.79',
#    '5. adjusted close': '136.24743593202',
#    '6. volume': '3697975',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-23': {'1. open': '136.63',
#    '2. high': '137.68',
#    '3. low': '135.87',
#    '4. close': '136.38',
#    '5. adjusted close': '134.853220933369',
#    '6. volume': '3457527',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-20': {'1. open': '138.15',
#    '2. high': '139.27',
#    '3. low': '137.12',
#    '4. close': '137.16',
#    '5. adjusted close': '135.624488804964',
#    '6. volume': '4865615',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-19': {'1. open': '138.64',
#    '2. high': '139.405',
#    '3. low': '137.93',
#    '4. close': '138.01',
#    '5. adjusted close': '136.464973024009',
#    '6. volume': '5314159',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-18': {'1. open': '140.0',
#    '2. high': '140.43',
#    '3. low': '139.58',
#    '4. close': '139.97',
#    '5. adjusted close': '138.40303075263',
#    '6. volume': '3329985',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-17': {'1. open': '137.12',
#    '2. high': '140.62',
#    '3. low': '136.31',
#    '4. close': '140.32',
#    '5. adjusted close': '138.749112489884',
#    '6. volume': '4172822',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-16': {'1. open': '139.28',
#    '2. high': '139.78',
#    '3. low': '138.52',
#    '4. close': '139.21',
#    '5. adjusted close': '137.651538980308',
#    '6. volume': '3361468',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-13': {'1. open': '139.77',
#    '2. high': '140.12',
#    '3. low': '138.27',
#    '4. close': '138.46',
#    '5. adjusted close': '136.909935257621',
#    '6. volume': '4583553',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-12': {'1. open': '142.51',
#    '2. high': '142.93',
#    '3. low': '140.95',
#    '4. close': '141.24',
#    '5. adjusted close': '139.65881305638',
#    '6. volume': '3921142',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-11': {'1. open': '142.51',
#    '2. high': '143.34',
#    '3. low': '142.14',
#    '4. close': '143.23',
#    '5. adjusted close': '141.626534933909',
#    '6. volume': '2511459',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-10': {'1. open': '142.6',
#    '2. high': '143.415',
#    '3. low': '141.72',
#    '4. close': '142.11',
#    '5. adjusted close': '140.519073374697',
#    '6. volume': '3015784',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-09': {'1. open': '142.3',
#    '2. high': '142.4',
#    '3. low': '140.68',
#    '4. close': '142.2',
#    '5. adjusted close': '140.608065821419',
#    '6. volume': '2354396',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-06': {'1. open': '141.4',
#    '2. high': '142.94',
#    '3. low': '140.11',
#    '4. close': '142.03',
#    '5. adjusted close': '140.43996897761',
#    '6. volume': '3511347',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-05': {'1. open': '140.9',
#    '2. high': '141.7',
#    '3. low': '140.19',
#    '4. close': '141.52',
#    '5. adjusted close': '139.935678446183',
#    '6. volume': '3223910',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-04': {'1. open': '140.37',
#    '2. high': '141.2004',
#    '3. low': '139.99',
#    '4. close': '141.07',
#    '5. adjusted close': '139.490716212571',
#    '6. volume': '2637779',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-03': {'1. open': '140.87',
#    '2. high': '141.64',
#    '3. low': '140.0',
#    '4. close': '140.39',
#    '5. adjusted close': '138.818328837335',
#    '6. volume': '3284421',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-10-02': {'1. open': '140.04',
#    '2. high': '141.45',
#    '3. low': '139.86',
#    '4. close': '140.8',
#    '5. adjusted close': '139.223738872404',
#    '6. volume': '3275461',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-29': {'1. open': '142.0',
#    '2. high': '142.13',
#    '3. low': '139.61',
#    '4. close': '140.3',
#    '5. adjusted close': '138.729336390612',
#    '6. volume': '5703983',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-28': {'1. open': '142.14',
#    '2. high': '142.282',
#    '3. low': '140.205',
#    '4. close': '141.58',
#    '5. adjusted close': '139.995006743998',
#    '6. volume': '5783422',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-27': {'1. open': '143.67',
#    '2. high': '143.82',
#    '3. low': '141.76',
#    '4. close': '143.17',
#    '5. adjusted close': '141.567206636094',
#    '6. volume': '4439121',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-26': {'1. open': '145.51',
#    '2. high': '146.17',
#    '3. low': '143.0201',
#    '4. close': '143.24',
#    '5. adjusted close': '141.636422983545',
#    '6. volume': '4824654',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-25': {'1. open': '146.57',
#    '2. high': '147.43',
#    '3. low': '146.25',
#    '4. close': '146.48',
#    '5. adjusted close': '144.840151065552',
#    '6. volume': '2694245',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-22': {'1. open': '147.41',
#    '2. high': '148.1',
#    '3. low': '146.82',
#    '4. close': '146.91',
#    '5. adjusted close': '145.265337199892',
#    '6. volume': '2562216',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-21': {'1. open': '149.0',
#    '2. high': '149.25',
#    '3. low': '147.31',
#    '4. close': '147.38',
#    '5. adjusted close': '145.730075532776',
#    '6. volume': '4944786',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-20': {'1. open': '148.36',
#    '2. high': '151.9299',
#    '3. low': '148.13',
#    '4. close': '149.83',
#    '5. adjusted close': '148.152647693553',
#    '6. volume': '9636681',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-19': {'1. open': '145.0',
#    '2. high': '146.72',
#    '3. low': '144.66',
#    '4. close': '146.52',
#    '5. adjusted close': '144.879703264095',
#    '6. volume': '3945423',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-18': {'1. open': '145.77',
#    '2. high': '146.48',
#    '3. low': '145.06',
#    '4. close': '145.09',
#    '5. adjusted close': '143.465712166172',
#    '6. volume': '2508062',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-15': {'1. open': '147.11',
#    '2. high': '147.85',
#    '3. low': '145.53',
#    '4. close': '145.99',
#    '5. adjusted close': '144.355636633396',
#    '6. volume': '6234033',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-14': {'1. open': '147.38',
#    '2. high': '147.73',
#    '3. low': '146.48',
#    '4. close': '147.35',
#    '5. adjusted close': '145.700411383868',
#    '6. volume': '2723200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-13': {'1. open': '145.95',
#    '2. high': '146.98',
#    '3. low': '145.92',
#    '4. close': '146.55',
#    '5. adjusted close': '144.909367413002',
#    '6. volume': '2627999',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-12': {'1. open': '147.92',
#    '2. high': '148.0',
#    '3. low': '145.8',
#    '4. close': '146.3',
#    '5. adjusted close': '144.662166172107',
#    '6. volume': '4457695',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-11': {'1. open': '148.57',
#    '2. high': '148.78',
#    '3. low': '147.58',
#    '4. close': '148.38',
#    '5. adjusted close': '146.718880496358',
#    '6. volume': '3273720',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-08': {'1. open': '147.35',
#    '2. high': '148.59',
#    '3. low': '147.26',
#    '4. close': '147.68',
#    '5. adjusted close': '146.026717021851',
#    '6. volume': '3722927',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-07': {'1. open': '148.13',
#    '2. high': '148.78',
#    '3. low': '147.4',
#    '4. close': '147.52',
#    '5. adjusted close': '145.868508227677',
#    '6. volume': '3333040',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-06': {'1. open': '147.66',
#    '2. high': '148.33',
#    '3. low': '147.12',
#    '4. close': '148.06',
#    '5. adjusted close': '146.402462908012',
#    '6. volume': '2932203',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-05': {'1. open': '147.91',
#    '2. high': '149.0',
#    '3. low': '147.5719',
#    '4. close': '148.13',
#    '5. adjusted close': '146.471679255463',
#    '6. volume': '3731281',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-09-01': {'1. open': '147.26',
#    '2. high': '148.1',
#    '3. low': '146.92',
#    '4. close': '147.94',
#    '5. adjusted close': '146.283806312382',
#    '6. volume': '2727796',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-31': {'1. open': '146.94',
#    '2. high': '147.7275',
#    '3. low': '146.54',
#    '4. close': '146.83',
#    '5. adjusted close': '145.186232802806',
#    '6. volume': '3885949',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-30': {'1. open': '146.42',
#    '2. high': '146.92',
#    '3. low': '145.7452',
#    '4. close': '146.86',
#    '5. adjusted close': '145.215896951713',
#    '6. volume': '2245402',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-29': {'1. open': '146.3',
#    '2. high': '146.73',
#    '3. low': '145.62',
#    '4. close': '146.45',
#    '5. adjusted close': '144.810486916644',
#    '6. volume': '2778113',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-28': {'1. open': '145.41',
#    '2. high': '146.74',
#    '3. low': '145.21',
#    '4. close': '146.02',
#    '5. adjusted close': '144.385300782304',
#    '6. volume': '3561347',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-25': {'1. open': '144.18',
#    '2. high': '145.47',
#    '3. low': '143.5',
#    '4. close': '145.35',
#    '5. adjusted close': '143.722801456704',
#    '6. volume': '3660147',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-24': {'1. open': '143.505',
#    '2. high': '144.47',
#    '3. low': '143.22',
#    '4. close': '143.55',
#    '5. adjusted close': '141.942952522255',
#    '6. volume': '2900244',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-23': {'1. open': '141.72',
#    '2. high': '143.475',
#    '3. low': '141.58',
#    '4. close': '143.41',
#    '5. adjusted close': '141.804519827354',
#    '6. volume': '2559083',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-22': {'1. open': '142.66',
#    '2. high': '143.225',
#    '3. low': '141.3',
#    '4. close': '141.49',
#    '5. adjusted close': '139.906014297275',
#    '6. volume': '3557734',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-21': {'1. open': '141.42',
#    '2. high': '142.39',
#    '3. low': '141.11',
#    '4. close': '142.28',
#    '5. adjusted close': '140.687170218506',
#    '6. volume': '2937781',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-18': {'1. open': '140.0',
#    '2. high': '141.83',
#    '3. low': '139.76',
#    '4. close': '141.41',
#    '5. adjusted close': '139.826909900189',
#    '6. volume': '3915480',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-17': {'1. open': '141.01',
#    '2. high': '142.66',
#    '3. low': '140.6',
#    '4. close': '140.66',
#    '5. adjusted close': '139.085306177502',
#    '6. volume': '3742058',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-16': {'1. open': '141.7',
#    '2. high': '142.09',
#    '3. low': '140.56',
#    '4. close': '140.64',
#    '5. adjusted close': '139.06553007823',
#    '6. volume': '3285347',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-15': {'1. open': '141.5',
#    '2. high': '142.31',
#    '3. low': '141.2',
#    '4. close': '141.87',
#    '5. adjusted close': '140.281760183437',
#    '6. volume': '3656559',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-14': {'1. open': '143.05',
#    '2. high': '143.365',
#    '3. low': '141.802',
#    '4. close': '141.91',
#    '5. adjusted close': '140.32131238198',
#    '6. volume': '4226563',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-11': {'1. open': '143.12',
#    '2. high': '143.45',
#    '3. low': '142.205',
#    '4. close': '143.12',
#    '5. adjusted close': '141.517766387915',
#    '6. volume': '2526433',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-10': {'1. open': '143.04',
#    '2. high': '144.58',
#    '3. low': '142.69',
#    '4. close': '143.25',
#    '5. adjusted close': '141.64631103318',
#    '6. volume': '4735763',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-09': {'1. open': '144.94',
#    '2. high': '144.94',
#    '3. low': '142.3',
#    '4. close': '142.49',
#    '5. adjusted close': '140.894819260858',
#    '6. volume': '4073038',
#    '7. dividend amount': '1.6600',
#    '8. split coefficient': '1.0'},
#   '2023-08-08': {'1. open': '145.7',
#    '2. high': '146.15',
#    '3. low': '144.11',
#    '4. close': '145.91',
#    '5. adjusted close': '142.615075118639',
#    '6. volume': '4654582',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-07': {'1. open': '145.0',
#    '2. high': '146.5',
#    '3. low': '144.93',
#    '4. close': '146.18',
#    '5. adjusted close': '142.878978005912',
#    '6. volume': '3438654',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-04': {'1. open': '145.09',
#    '2. high': '146.09',
#    '3. low': '143.99',
#    '4. close': '144.24',
#    '5. adjusted close': '140.982786889949',
#    '6. volume': '4223204',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-03': {'1. open': '143.78',
#    '2. high': '145.22',
#    '3. low': '143.3116',
#    '4. close': '144.45',
#    '5. adjusted close': '141.188044691161',
#    '6. volume': '3952640',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-02': {'1. open': '142.78',
#    '2. high': '144.3',
#    '3. low': '142.31',
#    '4. close': '144.17',
#    '5. adjusted close': '140.914367622878',
#    '6. volume': '4959381',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-08-01': {'1. open': '144.25',
#    '2. high': '144.48',
#    '3. low': '142.17',
#    '4. close': '143.33',
#    '5. adjusted close': '140.093336418028',
#    '6. volume': '4798703',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-31': {'1. open': '143.81',
#    '2. high': '144.605',
#    '3. low': '143.53',
#    '4. close': '144.18',
#    '5. adjusted close': '140.924141803888',
#    '6. volume': '6138902',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-28': {'1. open': '143.44',
#    '2. high': '143.95',
#    '3. low': '142.85',
#    '4. close': '143.45',
#    '5. adjusted close': '140.21062659015',
#    '6. volume': '6686627',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-27': {'1. open': '142.3',
#    '2. high': '143.38',
#    '3. low': '141.9',
#    '4. close': '142.97',
#    '5. adjusted close': '139.741465901664',
#    '6. volume': '6331563',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-26': {'1. open': '140.44',
#    '2. high': '141.25',
#    '3. low': '139.88',
#    '4. close': '141.07',
#    '5. adjusted close': '137.884371509741',
#    '6. volume': '4046441',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-25': {'1. open': '139.42',
#    '2. high': '140.43',
#    '3. low': '139.0403',
#    '4. close': '140.33',
#    '5. adjusted close': '137.161082114993',
#    '6. volume': '3770813',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-24': {'1. open': '139.35',
#    '2. high': '140.12',
#    '3. low': '138.7788',
#    '4. close': '139.54',
#    '5. adjusted close': '136.388921815193',
#    '6. volume': '3475442',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-21': {'1. open': '138.21',
#    '2. high': '139.7799',
#    '3. low': '137.76',
#    '4. close': '138.94',
#    '5. adjusted close': '135.802470954586',
#    '6. volume': '5858741',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-20': {'1. open': '137.19',
#    '2. high': '140.32',
#    '3. low': '136.56',
#    '4. close': '138.38',
#    '5. adjusted close': '135.255116818019',
#    '6. volume': '10896330',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-19': {'1. open': '135.53',
#    '2. high': '136.45',
#    '3. low': '135.19',
#    '4. close': '135.48',
#    '5. adjusted close': '132.420604325085',
#    '6. volume': '5519992',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-18': {'1. open': '134.71',
#    '2. high': '135.95',
#    '3. low': '134.29',
#    '4. close': '135.36',
#    '5. adjusted close': '132.303314152964',
#    '6. volume': '3852058',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-17': {'1. open': '133.26',
#    '2. high': '134.61',
#    '3. low': '133.1',
#    '4. close': '134.24',
#    '5. adjusted close': '131.20860587983',
#    '6. volume': '3168419',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-14': {'1. open': '133.91',
#    '2. high': '133.92',
#    '3. low': '132.94',
#    '4. close': '133.4',
#    '5. adjusted close': '130.38757467498',
#    '6. volume': '2861496',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-13': {'1. open': '133.51',
#    '2. high': '135.07',
#    '3. low': '133.36',
#    '4. close': '133.92',
#    '5. adjusted close': '130.895832087507',
#    '6. volume': '3221422',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-12': {'1. open': '135.07',
#    '2. high': '135.33',
#    '3. low': '132.575',
#    '4. close': '132.84',
#    '5. adjusted close': '129.840220538414',
#    '6. volume': '3732189',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-11': {'1. open': '133.66',
#    '2. high': '134.56',
#    '3. low': '133.23',
#    '4. close': '134.44',
#    '5. adjusted close': '131.404089500033',
#    '6. volume': '2925238',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'}}}

# %%
api.call_api(endpoint)
# Out:
# <Response [200]>

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
r = requests.get(endpoint)
data = r.json()

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2023-11-29',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-11-29': {'1. open': '156.1500',
#    '2. high': '157.5100',
#    '3. low': '156.0200',
#    '4. close': '156.4100',
#    '5. volume': '3568887'},
#   '2023-11-28': {'1. open': '155.4400',
#    '2. high': '155.7450',
#    '3. low': '154.8600',
#    '4. close': '155.6500',
#    '5. volume': '2666182'},
#   '2023-11-27': {'1. open': '154.9900',
#    '2. high': '156.1350',
#    '3. low': '154.7500',
#    '4. close': '155.5700',
#    '5. volume': '4053093'},
#   '2023-11-24': {'1. open': '155.1300',
#    '2. high': '155.4000',
#    '3. low': '153.9200',
#    '4. close': '155.1800',
#    '5. volume': '1799161'},
#   '2023-11-22': {'1. open': '154.5000',
#    '2. high': '155.7050',
#    '3. low': '154.1600',
#    '4. close': '155.1300',
#    '5. volume': '3045091'},
#   '2023-11-21': {'1. open': '154.6000',
#    '2. high': '154.6600',
#    '3. low': '153.5100',
#    '4. close': '153.9100',
#    '5. volume': '2859508'},
#   '2023-11-20': {'1. open': '152.5100',
#    '2. high': '154.6800',
#    '3. low': '152.3500',
#    '4. close': '154.3500',
#    '5. volume': '3658936'},
#   '2023-11-17': {'1. open': '153.2900',
#    '2. high': '153.5000',
#    '3. low': '152.4601',
#    '4. close': '152.8900',
#    '5. volume': '4426676'},
#   '2023-11-16': {'1. open': '153.0000',
#    '2. high': '153.3500',
#    '3. low': '152.1300',
#    '4. close': '153.0600',
#    '5. volume': '3519172'},
#   '2023-11-15': {'1. open': '150.4000',
#    '2. high': '153.2200',
#    '3. low': '150.4000',
#    '4. close': '152.5800',
#    '5. volume': '4632519'},
#   '2023-11-14': {'1. open': '149.4500',
#    '2. high': '150.8063',
#    '3. low': '149.0500',
#    '4. close': '150.4100',
#    '5. volume': '4321940'},
#   '2023-11-13': {'1. open': '148.4600',
#    '2. high': '148.4900',
#    '3. low': '147.3500',
#    '4. close': '148.1000',
#    '5. volume': '2647288'},
#   '2023-11-10': {'1. open': '147.4400',
#    '2. high': '149.1700',
#    '3. low': '146.8500',
#    '4. close': '149.0200',
#    '5. volume': '3179541'},
#   '2023-11-09': {'1. open': '146.5500',
#    '2. high': '146.9900',
#    '3. low': '145.2800',
#    '4. close': '146.6200',
#    '5. volume': '3412713'},
#   '2023-11-08': {'1. open': '149.2500',
#    '2. high': '149.6800',
#    '3. low': '147.5850',
#    '4. close': '148.0300',
#    '5. volume': '3618588'},
#   '2023-11-07': {'1. open': '149.0300',
#    '2. high': '149.2800',
#    '3. low': '148.0300',
#    '4. close': '148.8300',
#    '5. volume': '3549853'},
#   '2023-11-06': {'1. open': '147.8900',
#    '2. high': '149.2250',
#    '3. low': '147.8500',
#    '4. close': '148.9700',
#    '5. volume': '4597249'},
#   '2023-11-03': {'1. open': '147.4500',
#    '2. high': '148.4450',
#    '3. low': '147.2800',
#    '4. close': '147.9000',
#    '5. volume': '3510495'},
#   '2023-11-02': {'1. open': '145.7700',
#    '2. high': '147.1000',
#    '3. low': '144.8400',
#    '4. close': '147.0100',
#    '5. volume': '3902657'},
#   '2023-11-01': {'1. open': '145.0000',
#    '2. high': '146.5100',
#    '3. low': '144.4500',
#    '4. close': '145.4000',
#    '5. volume': '4750081'},
#   '2023-10-31': {'1. open': '143.0000',
#    '2. high': '144.7600',
#    '3. low': '142.5900',
#    '4. close': '144.6400',
#    '5. volume': '6592041'},
#   '2023-10-30': {'1. open': '143.1900',
#    '2. high': '144.5000',
#    '3. low': '142.5800',
#    '4. close': '142.6300',
#    '5. volume': '4204190'},
#   '2023-10-27': {'1. open': '143.6200',
#    '2. high': '144.7000',
#    '3. low': '141.7100',
#    '4. close': '142.5200',
#    '5. volume': '5469227'},
#   '2023-10-26': {'1. open': '142.2000',
#    '2. high': '144.4100',
#    '3. low': '141.5800',
#    '4. close': '143.7600',
#    '5. volume': '11130170'},
#   '2023-10-25': {'1. open': '137.5000',
#    '2. high': '138.4900',
#    '3. low': '136.3300',
#    '4. close': '137.0800',
#    '5. volume': '6472549'},
#   '2023-10-24': {'1. open': '136.7400',
#    '2. high': '137.9800',
#    '3. low': '136.0500',
#    '4. close': '137.7900',
#    '5. volume': '3697975'},
#   '2023-10-23': {'1. open': '136.6300',
#    '2. high': '137.6800',
#    '3. low': '135.8700',
#    '4. close': '136.3800',
#    '5. volume': '3457527'},
#   '2023-10-20': {'1. open': '138.1500',
#    '2. high': '139.2700',
#    '3. low': '137.1200',
#    '4. close': '137.1600',
#    '5. volume': '4865615'},
#   '2023-10-19': {'1. open': '138.6400',
#    '2. high': '139.4050',
#    '3. low': '137.9300',
#    '4. close': '138.0100',
#    '5. volume': '5314159'},
#   '2023-10-18': {'1. open': '140.0000',
#    '2. high': '140.4300',
#    '3. low': '139.5800',
#    '4. close': '139.9700',
#    '5. volume': '3329985'},
#   '2023-10-17': {'1. open': '137.1200',
#    '2. high': '140.6200',
#    '3. low': '136.3100',
#    '4. close': '140.3200',
#    '5. volume': '4172822'},
#   '2023-10-16': {'1. open': '139.2800',
#    '2. high': '139.7800',
#    '3. low': '138.5200',
#    '4. close': '139.2100',
#    '5. volume': '3361468'},
#   '2023-10-13': {'1. open': '139.7700',
#    '2. high': '140.1200',
#    '3. low': '138.2700',
#    '4. close': '138.4600',
#    '5. volume': '4583553'},
#   '2023-10-12': {'1. open': '142.5100',
#    '2. high': '142.9300',
#    '3. low': '140.9500',
#    '4. close': '141.2400',
#    '5. volume': '3921142'},
#   '2023-10-11': {'1. open': '142.5100',
#    '2. high': '143.3400',
#    '3. low': '142.1400',
#    '4. close': '143.2300',
#    '5. volume': '2511459'},
#   '2023-10-10': {'1. open': '142.6000',
#    '2. high': '143.4150',
#    '3. low': '141.7200',
#    '4. close': '142.1100',
#    '5. volume': '3015784'},
#   '2023-10-09': {'1. open': '142.3000',
#    '2. high': '142.4000',
#    '3. low': '140.6800',
#    '4. close': '142.2000',
#    '5. volume': '2354396'},
#   '2023-10-06': {'1. open': '141.4000',
#    '2. high': '142.9400',
#    '3. low': '140.1100',
#    '4. close': '142.0300',
#    '5. volume': '3511347'},
#   '2023-10-05': {'1. open': '140.9000',
#    '2. high': '141.7000',
#    '3. low': '140.1900',
#    '4. close': '141.5200',
#    '5. volume': '3223910'},
#   '2023-10-04': {'1. open': '140.3700',
#    '2. high': '141.2004',
#    '3. low': '139.9900',
#    '4. close': '141.0700',
#    '5. volume': '2637779'},
#   '2023-10-03': {'1. open': '140.8700',
#    '2. high': '141.6400',
#    '3. low': '140.0000',
#    '4. close': '140.3900',
#    '5. volume': '3284421'},
#   '2023-10-02': {'1. open': '140.0400',
#    '2. high': '141.4500',
#    '3. low': '139.8600',
#    '4. close': '140.8000',
#    '5. volume': '3275461'},
#   '2023-09-29': {'1. open': '142.0000',
#    '2. high': '142.1300',
#    '3. low': '139.6100',
#    '4. close': '140.3000',
#    '5. volume': '5703983'},
#   '2023-09-28': {'1. open': '142.1400',
#    '2. high': '142.2820',
#    '3. low': '140.2050',
#    '4. close': '141.5800',
#    '5. volume': '5783422'},
#   '2023-09-27': {'1. open': '143.6700',
#    '2. high': '143.8200',
#    '3. low': '141.7600',
#    '4. close': '143.1700',
#    '5. volume': '4439121'},
#   '2023-09-26': {'1. open': '145.5100',
#    '2. high': '146.1700',
#    '3. low': '143.0201',
#    '4. close': '143.2400',
#    '5. volume': '4824654'},
#   '2023-09-25': {'1. open': '146.5700',
#    '2. high': '147.4300',
#    '3. low': '146.2500',
#    '4. close': '146.4800',
#    '5. volume': '2694245'},
#   '2023-09-22': {'1. open': '147.4100',
#    '2. high': '148.1000',
#    '3. low': '146.8200',
#    '4. close': '146.9100',
#    '5. volume': '2562216'},
#   '2023-09-21': {'1. open': '149.0000',
#    '2. high': '149.2500',
#    '3. low': '147.3100',
#    '4. close': '147.3800',
#    '5. volume': '4944786'},
#   '2023-09-20': {'1. open': '148.3600',
#    '2. high': '151.9299',
#    '3. low': '148.1300',
#    '4. close': '149.8300',
#    '5. volume': '9636681'},
#   '2023-09-19': {'1. open': '145.0000',
#    '2. high': '146.7200',
#    '3. low': '144.6600',
#    '4. close': '146.5200',
#    '5. volume': '3945423'},
#   '2023-09-18': {'1. open': '145.7700',
#    '2. high': '146.4800',
#    '3. low': '145.0600',
#    '4. close': '145.0900',
#    '5. volume': '2508062'},
#   '2023-09-15': {'1. open': '147.1100',
#    '2. high': '147.8500',
#    '3. low': '145.5300',
#    '4. close': '145.9900',
#    '5. volume': '6234033'},
#   '2023-09-14': {'1. open': '147.3800',
#    '2. high': '147.7300',
#    '3. low': '146.4800',
#    '4. close': '147.3500',
#    '5. volume': '2723200'},
#   '2023-09-13': {'1. open': '145.9500',
#    '2. high': '146.9800',
#    '3. low': '145.9200',
#    '4. close': '146.5500',
#    '5. volume': '2627999'},
#   '2023-09-12': {'1. open': '147.9200',
#    '2. high': '148.0000',
#    '3. low': '145.8000',
#    '4. close': '146.3000',
#    '5. volume': '4457695'},
#   '2023-09-11': {'1. open': '148.5700',
#    '2. high': '148.7800',
#    '3. low': '147.5800',
#    '4. close': '148.3800',
#    '5. volume': '3273720'},
#   '2023-09-08': {'1. open': '147.3500',
#    '2. high': '148.5900',
#    '3. low': '147.2600',
#    '4. close': '147.6800',
#    '5. volume': '3722927'},
#   '2023-09-07': {'1. open': '148.1300',
#    '2. high': '148.7800',
#    '3. low': '147.4000',
#    '4. close': '147.5200',
#    '5. volume': '3333040'},
#   '2023-09-06': {'1. open': '147.6600',
#    '2. high': '148.3300',
#    '3. low': '147.1200',
#    '4. close': '148.0600',
#    '5. volume': '2932203'},
#   '2023-09-05': {'1. open': '147.9100',
#    '2. high': '149.0000',
#    '3. low': '147.5719',
#    '4. close': '148.1300',
#    '5. volume': '3731281'},
#   '2023-09-01': {'1. open': '147.2600',
#    '2. high': '148.1000',
#    '3. low': '146.9200',
#    '4. close': '147.9400',
#    '5. volume': '2727796'},
#   '2023-08-31': {'1. open': '146.9400',
#    '2. high': '147.7275',
#    '3. low': '146.5400',
#    '4. close': '146.8300',
#    '5. volume': '3885949'},
#   '2023-08-30': {'1. open': '146.4200',
#    '2. high': '146.9200',
#    '3. low': '145.7452',
#    '4. close': '146.8600',
#    '5. volume': '2245402'},
#   '2023-08-29': {'1. open': '146.3000',
#    '2. high': '146.7300',
#    '3. low': '145.6200',
#    '4. close': '146.4500',
#    '5. volume': '2778113'},
#   '2023-08-28': {'1. open': '145.4100',
#    '2. high': '146.7400',
#    '3. low': '145.2100',
#    '4. close': '146.0200',
#    '5. volume': '3561347'},
#   '2023-08-25': {'1. open': '144.1800',
#    '2. high': '145.4700',
#    '3. low': '143.5000',
#    '4. close': '145.3500',
#    '5. volume': '3660147'},
#   '2023-08-24': {'1. open': '143.5050',
#    '2. high': '144.4700',
#    '3. low': '143.2200',
#    '4. close': '143.5500',
#    '5. volume': '2900244'},
#   '2023-08-23': {'1. open': '141.7200',
#    '2. high': '143.4750',
#    '3. low': '141.5800',
#    '4. close': '143.4100',
#    '5. volume': '2559083'},
#   '2023-08-22': {'1. open': '142.6600',
#    '2. high': '143.2250',
#    '3. low': '141.3000',
#    '4. close': '141.4900',
#    '5. volume': '3557734'},
#   '2023-08-21': {'1. open': '141.4200',
#    '2. high': '142.3900',
#    '3. low': '141.1100',
#    '4. close': '142.2800',
#    '5. volume': '2937781'},
#   '2023-08-18': {'1. open': '140.0000',
#    '2. high': '141.8300',
#    '3. low': '139.7600',
#    '4. close': '141.4100',
#    '5. volume': '3915480'},
#   '2023-08-17': {'1. open': '141.0100',
#    '2. high': '142.6600',
#    '3. low': '140.6000',
#    '4. close': '140.6600',
#    '5. volume': '3742058'},
#   '2023-08-16': {'1. open': '141.7000',
#    '2. high': '142.0900',
#    '3. low': '140.5600',
#    '4. close': '140.6400',
#    '5. volume': '3285347'},
#   '2023-08-15': {'1. open': '141.5000',
#    '2. high': '142.3100',
#    '3. low': '141.2000',
#    '4. close': '141.8700',
#    '5. volume': '3656559'},
#   '2023-08-14': {'1. open': '143.0500',
#    '2. high': '143.3650',
#    '3. low': '141.8020',
#    '4. close': '141.9100',
#    '5. volume': '4226563'},
#   '2023-08-11': {'1. open': '143.1200',
#    '2. high': '143.4500',
#    '3. low': '142.2050',
#    '4. close': '143.1200',
#    '5. volume': '2526433'},
#   '2023-08-10': {'1. open': '143.0400',
#    '2. high': '144.5800',
#    '3. low': '142.6900',
#    '4. close': '143.2500',
#    '5. volume': '4735763'},
#   '2023-08-09': {'1. open': '144.9400',
#    '2. high': '144.9400',
#    '3. low': '142.3000',
#    '4. close': '142.4900',
#    '5. volume': '4073038'},
#   '2023-08-08': {'1. open': '145.7000',
#    '2. high': '146.1500',
#    '3. low': '144.1100',
#    '4. close': '145.9100',
#    '5. volume': '4654582'},
#   '2023-08-07': {'1. open': '145.0000',
#    '2. high': '146.5000',
#    '3. low': '144.9300',
#    '4. close': '146.1800',
#    '5. volume': '3438654'},
#   '2023-08-04': {'1. open': '145.0900',
#    '2. high': '146.0900',
#    '3. low': '143.9900',
#    '4. close': '144.2400',
#    '5. volume': '4223204'},
#   '2023-08-03': {'1. open': '143.7800',
#    '2. high': '145.2200',
#    '3. low': '143.3116',
#    '4. close': '144.4500',
#    '5. volume': '3952640'},
#   '2023-08-02': {'1. open': '142.7800',
#    '2. high': '144.3000',
#    '3. low': '142.3100',
#    '4. close': '144.1700',
#    '5. volume': '4959381'},
#   '2023-08-01': {'1. open': '144.2500',
#    '2. high': '144.4800',
#    '3. low': '142.1700',
#    '4. close': '143.3300',
#    '5. volume': '4798703'},
#   '2023-07-31': {'1. open': '143.8100',
#    '2. high': '144.6050',
#    '3. low': '143.5300',
#    '4. close': '144.1800',
#    '5. volume': '6138902'},
#   '2023-07-28': {'1. open': '143.4400',
#    '2. high': '143.9500',
#    '3. low': '142.8500',
#    '4. close': '143.4500',
#    '5. volume': '6686627'},
#   '2023-07-27': {'1. open': '142.3000',
#    '2. high': '143.3800',
#    '3. low': '141.9000',
#    '4. close': '142.9700',
#    '5. volume': '6331563'},
#   '2023-07-26': {'1. open': '140.4400',
#    '2. high': '141.2500',
#    '3. low': '139.8800',
#    '4. close': '141.0700',
#    '5. volume': '4046441'},
#   '2023-07-25': {'1. open': '139.4200',
#    '2. high': '140.4300',
#    '3. low': '139.0403',
#    '4. close': '140.3300',
#    '5. volume': '3770813'},
#   '2023-07-24': {'1. open': '139.3500',
#    '2. high': '140.1200',
#    '3. low': '138.7788',
#    '4. close': '139.5400',
#    '5. volume': '3475442'},
#   '2023-07-21': {'1. open': '138.2100',
#    '2. high': '139.7799',
#    '3. low': '137.7600',
#    '4. close': '138.9400',
#    '5. volume': '5858741'},
#   '2023-07-20': {'1. open': '137.1900',
#    '2. high': '140.3200',
#    '3. low': '136.5600',
#    '4. close': '138.3800',
#    '5. volume': '10896330'},
#   '2023-07-19': {'1. open': '135.5300',
#    '2. high': '136.4500',
#    '3. low': '135.1900',
#    '4. close': '135.4800',
#    '5. volume': '5519992'},
#   '2023-07-18': {'1. open': '134.7100',
#    '2. high': '135.9500',
#    '3. low': '134.2900',
#    '4. close': '135.3600',
#    '5. volume': '3852058'},
#   '2023-07-17': {'1. open': '133.2600',
#    '2. high': '134.6100',
#    '3. low': '133.1000',
#    '4. close': '134.2400',
#    '5. volume': '3168419'},
#   '2023-07-14': {'1. open': '133.9100',
#    '2. high': '133.9200',
#    '3. low': '132.9400',
#    '4. close': '133.4000',
#    '5. volume': '2861496'},
#   '2023-07-13': {'1. open': '133.5100',
#    '2. high': '135.0700',
#    '3. low': '133.3600',
#    '4. close': '133.9200',
#    '5. volume': '3221422'},
#   '2023-07-12': {'1. open': '135.0700',
#    '2. high': '135.3300',
#    '3. low': '132.5750',
#    '4. close': '132.8400',
#    '5. volume': '3732189'},
#   '2023-07-11': {'1. open': '133.6600',
#    '2. high': '134.5600',
#    '3. low': '133.2300',
#    '4. close': '134.4400',
#    '5. volume': '2925238'}}}

# %%
# Out:
# <Response [200]>
